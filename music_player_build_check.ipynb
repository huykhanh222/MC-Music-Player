# %%
<VSCode.Cell id="#VSC-18988c1e" language="markdown">
# Project Overview and Existing File Review

Inspect the Fabric example mod files and verify the source layout before making changes.
</VSCode.Cell>
# Out:
#   Cell In[1], line 3
#     Inspect the Fabric example mod files and verify the source layout before making changes.
#             ^
# SyntaxError: invalid syntax
